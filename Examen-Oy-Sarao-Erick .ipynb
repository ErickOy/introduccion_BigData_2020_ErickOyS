# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("data.csv")

# %%
data.head(5)
# Out:
#    acousticness                            artists  danceability  duration_ms  \
# 1         0.643          ["Screamin' Jay Hawkins"]         0.852       150200
# 8         0.996               ['Francisco Canaro']         0.469       146840
# 5         0.996  ['Mamie Smith & Her Jazz Hounds']         0.424       198627
# 7         0.996  ['Mamie Smith & Her Jazz Hounds']         0.474       186173
# 0         0.991                    ['Mamie Smith']         0.598       168333
#
#    energy  explicit                      id  instrumentalness  key  liveness  \
# 1   0.517         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 8   0.238         0  02i59gYdjlhBmbbWhf8YuK          0.960000    8    0.1490
# 5   0.245         0  3HnrHGLE9u2MjHtdobfWl9          0.799000    5    0.2350
# 7   0.239         0  02FzJbHtqElixxCmrpSCUa          0.186000    9    0.1950
# 0   0.224         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
#
# ...

# %% [markdown]
# ## Alfabeticamente

# %%
orden = data.head(10).sort_values(by='artists', ascending=True)

# %%
orden['artists']
# Out:
# 1            ["Screamin' Jay Hawkins"]
# 8                 ['Francisco Canaro']
# 5    ['Mamie Smith & Her Jazz Hounds']
# 7    ['Mamie Smith & Her Jazz Hounds']
# 0                      ['Mamie Smith']
# 2                      ['Mamie Smith']
# 6                      ['Mamie Smith']
# 9                           ['Meetya']
# 4                             ['Mixe']
# 3                  ['Oscar Velazquez']
# Name: artists, dtype: object

# %% [markdown]
# ## Relacionar

# %%
data.corr
# Out:
# <bound method DataFrame.corr of    acousticness                            artists  danceability  duration_ms  \
# 1      0.643000          ["Screamin' Jay Hawkins"]         0.852       150200
# 8      0.996000               ['Francisco Canaro']         0.469       146840
# 5      0.996000  ['Mamie Smith & Her Jazz Hounds']         0.424       198627
# 7      0.996000  ['Mamie Smith & Her Jazz Hounds']         0.474       186173
# 0      0.991000                    ['Mamie Smith']         0.598       168333
# 2      0.993000                    ['Mamie Smith']         0.647       163827
# 6      0.992000                    ['Mamie Smith']         0.782       195200
# 9      0.006820                         ['Meetya']         0.571       476304
# 4      0.295000                           ['Mixe']         0.704       165224
# 3      0.000173                ['Oscar Velazquez']         0.730       422087
#
#    energy  explicit                      id  instrumentalness  key  liveness  \
# ...

# %%
relation = data[['artists','danceability','energy','instrumentalness']]

# %%
relation
# Out:
#                              artists  danceability  energy  instrumentalness
# 1          ["Screamin' Jay Hawkins"]         0.852  0.5170          0.026400
# 8               ['Francisco Canaro']         0.469  0.2380          0.960000
# 5  ['Mamie Smith & Her Jazz Hounds']         0.424  0.2450          0.799000
# 7  ['Mamie Smith & Her Jazz Hounds']         0.474  0.2390          0.186000
# 0                    ['Mamie Smith']         0.598  0.2240          0.000522
# 2                    ['Mamie Smith']         0.647  0.1860          0.000018
# 6                    ['Mamie Smith']         0.782  0.0573          0.000002
# 9                         ['Meetya']         0.571  0.7530          0.873000
# 4                           ['Mixe']         0.704  0.7070          0.000246
# 3                ['Oscar Velazquez']         0.730  0.7980          0.801000

# %% [markdown]
# ## Identificar variables

# %%
media = data.mean()
mediana = data.median()
moda =data.mode()

# %%
media
# Out:
# acousticness             0.690899
# danceability             0.625100
# duration_ms         227281.500000
# energy                   0.396430
# explicit                 0.100000
# instrumentalness         0.364619
# key                      5.700000
# liveness                 0.235590
# loudness               -10.462900
# mode                     0.700000
# popularity               5.600000
# speechiness              0.068680
# tempo                  110.989700
# valence                  0.468420
# year                  1920.000000
# dtype: float64

# %%
mediana
# Out:
# acousticness             0.9915
# danceability             0.6225
# duration_ms         177253.0000
# energy                   0.2420
# explicit                 0.0000
# instrumentalness         0.1062
# key                      5.0000
# liveness                 0.1855
# loudness               -10.5910
# mode                     1.0000
# popularity               4.5000
# speechiness              0.0563
# tempo                  112.9730
# valence                  0.4820
# year                  1920.0000
# dtype: float64

# %%
moda
# Out:
#    acousticness          artists  danceability  duration_ms  energy  explicit  \
# 0         0.996  ['Mamie Smith']         0.424       146840  0.0573       0.0
# 1           NaN              NaN         0.469       150200  0.1860       NaN
# 2           NaN              NaN         0.474       163827  0.2240       NaN
# 3           NaN              NaN         0.571       165224  0.2380       NaN
# 4           NaN              NaN         0.598       168333  0.2390       NaN
# 5           NaN              NaN         0.647       186173  0.2450       NaN
# 6           NaN              NaN         0.704       195200  0.5170       NaN
# 7           NaN              NaN         0.730       198627  0.7070       NaN
# 8           NaN              NaN         0.782       422087  0.7530       NaN
# 9           NaN              NaN         0.852       476304  0.7980       NaN
#
#                        id  instrumentalness  key  liveness  loudness  mode  \
# ...

# %%
data.describe()
# Out:
#        acousticness  danceability   duration_ms     energy   explicit  \
# count     10.000000     10.000000      10.00000  10.000000  10.000000
# mean       0.690899      0.625100  227281.50000   0.396430   0.100000
# std        0.428867      0.143415  118914.78051   0.271053   0.316228
# min        0.000173      0.424000  146840.00000   0.057300   0.000000
# 25%        0.382000      0.498250  164176.25000   0.227500   0.000000
# 50%        0.991500      0.622500  177253.00000   0.242000   0.000000
# 75%        0.995250      0.723500  197770.25000   0.659500   0.000000
# max        0.996000      0.852000  476304.00000   0.798000   1.000000
#
#        instrumentalness       key   liveness   loudness       mode  \
# count         10.000000  10.00000  10.000000  10.000000  10.000000
# mean           0.364619   5.70000   0.235590 -10.462900   0.700000
# std            0.430704   3.12872   0.148099   3.847131   0.483046
# ...

# %%
sns.pairplot(relation, kind='reg')
plt.show()

# %%
# puedo observar que la danceability con la energy, como de la energy con la instrumentalness, pueden tener correlación 
#positiva  en la cual aumentan simultaneamente a un ritmo constante, por lo cual es positiva y se puede ver que la relación lineal es debil
#por lo dispersado de los puntos.
